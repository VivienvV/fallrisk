# %%
import pandas as pd

data = pd.read_csv('WalkingDirection.txt')
# print(data)
new = data.drop(['Unnamed: 1'], axis=1)
print(new)

new.to_csv('WalkingDirection.csv', index=False)
# Out:
#      WalkingDirection
# 0                away
# 1             towards
# 2                away
# 3             towards
# 4             towards
# 5                away
# 6             towards
# 7                away
# 8                away
# 9             towards
# 10               away
# 11            towards
# 12               away
# 13            towards
# 14            towards
# 15               away
# 16            towards
# 17               away
# 18            towards
# 19            towards
# 20               away
# 21            towards
# 22            towards
# 23               away
# 24            towards
# 25               away
# 26            towards
# 27               away
# 28            towards
# 29               away
# ...               ...
# 1613          towards
# 1614             away
# 1615          towards
# 1616             away
# 1617          towards
# 1618             away
# 1619          towards
# 1620             away
# 1621          towards
# ...

# %%
data = pd.read_csv('Conditie.txt')
# print(data)
new = data.drop(['Unnamed: 1'], axis=1)
print(new)

new.to_csv('Conditie.csv', index=False)
# Out:
#      Conditie
# 0        norm
# 1        norm
# 2        norm
# 3        norm
# 4        norm
# 5        norm
# 6        norm
# 7        norm
# 8        norm
# 9        norm
# 10       norm
# 11       norm
# 12       norm
# 13       norm
# 14       norm
# 15       norm
# 16       norm
# 17       norm
# 18       norm
# 19       norm
# 20       norm
# 21       norm
# 22       norm
# 23       norm
# 24       norm
# 25       norm
# 26       norm
# 27       norm
# 28       norm
# 29       norm
# ...       ...
# 1632     bril
# 1633     bril
# 1634     bril
# 1635     bril
# 1636     bril
# 1637     bril
# 1638     bril
# 1639     bril
# 1640     bril
# 1641     bril
# 1642     bril
# 1643     bril
# 1644     bril
# 1645     bril
# 1646     bril
# 1647     bril
# 1648     bril
# 1649     bril
# 1650     bril
# 1651     bril
# 1652     bril
# 1653     bril
# 1654     bril
# 1655     bril
# 1656     bril
# 1657     bril
# 1658     bril
# 1659     bril
# 1660     bril
# 1661     bril
#
# ...

# %%
from scipy.io import loadmat
import pandas as pd
import numpy as np

# %%
matdata = loadmat("../Data/SpineMidData_21032018.mat", struct_as_record=False)

# %%
# print(matdata)

# %%
spineMidData=matdata['SpineMidData']
spineMidData[:1]
# Out:
# array([[array(['TestID'], dtype='<U6'), array(['Conditie'], dtype='<U8'),
#         array(['SubjectID'], dtype='<U9'),
#         array(['TrialNr'], dtype='<U7'),
#         array(['NumberOfSegments'], dtype='<U16'),
#         array(['SegmentNr'], dtype='<U9'),
#         array(['WalkingDirection'], dtype='<U16'),
#         array(['SegmentData'], dtype='<U11'),
#         array(['Alcohol'], dtype='<U7'), array(['Height'], dtype='<U6'),
#         array(['Weight'], dtype='<U6'), array(['Age'], dtype='<U3'),
#         array(['BMI'], dtype='<U3'),
#         array(['Balance_MLrange'], dtype='<U15'),
#         array(['Balance_MLstdev'], dtype='<U15'),
#         array(['Balance_MLmeanVelocity'], dtype='<U22'),
#         array(['Balance_APrange'], dtype='<U15'),
#         array(['Balance_APstdev'], dtype='<U15'),
#         array(['Balance_APmeanVelocity'], dtype='<U22'),
#         array(['Balance_MeanVelocity'], dtype='<U20'),
#         array(['GaitVelocity'], dtype='<U12'),
# ...

# %%
spineMidData[:,0]
# Out:
# array([array(['TestID'], dtype='<U6'), array(['001A01'], dtype='<U6'),
#        array(['001A01'], dtype='<U6'), ...,
#        array(['169B03'], dtype='<U6'), array(['169B03'], dtype='<U6'),
#        array(['169B03'], dtype='<U6')], dtype=object)

# %%
pd_data = pd.DataFrame(spineMidData)

# %%
# display(pd_data)

# %%
data = pd.read_csv("../Data/preprocessed_SpineMidData_withStringCols.csv") 
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(data)
# Out:
#      Unnamed: 0   TestID Conditie  SubjectID  SegmentNr WalkingDirection  \
# 0             0  004A01'     norm          4          1             away
# 1             1  004A01'     norm          4          2          towards
# 2             2  004A01'     norm          4          3             away
# 3             3  004A01'     norm          4          4          towards
# 4             4  006A01'     norm          6          1             away
# 5             5  006A01'     norm          6          2          towards
# 6             6  006A01'     norm          6          3             away
# 7             7  006A01'     norm          6          4          towards
# 8             8  009A01'     norm          9          1             away
# 9             9  009A01'     norm          9          2          towards
# 10           10  009A01'     norm          9          3             away
# 11           11  009A01'     norm          9          4          towards
# ...

# %%
data['Height'].mean()
# Out:
# 175.56473489519112

# %%
data.groupby('Conditie').count()
#Er zijn meer participants met bril die geen normale loop hebben. Dit komt doordat we het id van een deelnemer
#hebben verwijderd wanneer die deelnemer niet 4 segmenten had. Echter het kan zo zijn dat die deelnemer zonder bril
#maar drie segmenten had, maar met bril 4. Waardoor met bril achter blijft.
# Out:
#           Unnamed: 0  TestID  SubjectID  SegmentNr  WalkingDirection  \
# Conditie
# bril             415     415        415        415               415
# norm             396     396        396        396               396
#
#           SegmentData  Height  Weight  Age  BMI  Balance_MLrange  \
# Conditie
# bril              415     415     415  415  415              415
# norm              396     396     396  396  396              396
#
#           Balance_MLstdev  Balance_MLmeanVelocity  Balance_APrange  \
# Conditie
# bril                  415                     415              415
# norm                  396                     396              396
#
#           Balance_APstdev'  Balance_APmeanVelocity  Balance_MeanVelocity  \
# Conditie
# bril                   415                     415                   415
# norm                   396                     396                   396
#
#           GaitVelocity  MovementVelocity
# Conditie
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(data)
# Out:
#      Unnamed: 0   TestID Conditie  SubjectID  SegmentNr WalkingDirection  \
# 0             0  004A01'     norm          4          1             away
# 1             1  004A01'     norm          4          2          towards
# 2             2  004A01'     norm          4          3             away
# 3             3  004A01'     norm          4          4          towards
# 4             4  006A01'     norm          6          1             away
# 5             5  006A01'     norm          6          2          towards
# 6             6  006A01'     norm          6          3             away
# 7             7  006A01'     norm          6          4          towards
# 8             8  009A01'     norm          9          1             away
# 9             9  009A01'     norm          9          2          towards
# 10           10  009A01'     norm          9          3             away
# 11           11  009A01'     norm          9          4          towards
# ...

# %%
da = pd.read_csv("../Data/spineMidData_withStringCols.csv") 
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(da)
# Out:
#       Unnamed: 0   TestID Conditie  SubjectID  TrialNr  NumberOfSegments  \
# 0              0  001A01'     norm          1        1                 3
# 1              1  001A01'     norm          1        1                 3
# 2              2  001A01'     norm          1        1                 3
# 3              3  002A01'     norm          2        1                 2
# 4              4  002A01'     norm          2        1                 2
# 5              5  003A01'     norm          3        1                 3
# 6              6  003A01'     norm          3        1                 3
# 7              7  003A01'     norm          3        1                 3
# 8              8  004A01'     norm          4        1                 4
# 9              9  004A01'     norm          4        1                 4
# 10            10  004A01'     norm          4        1                 4
# 11            11  004A01'     norm          4        1                 4
# ...

# %%
da['Alcohol'].max()
# Out:
# 2.07

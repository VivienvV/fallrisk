# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_data = pd.read_csv("../Data/preprocessed_alcohol_balance.csv")
df_data = df_data.drop("Unnamed: 0", axis=1)
# display(df_data)

# %%
chars = ["array([[2]], dtype=uint8", "array", "\n", "[", "]", "(", ")"]

def string_to_ndarray(sd):
    for char in chars:
        sd = sd.replace(char, "")

    sd = sd.replace("   ", " ")
    sd = sd[:-2]

    sd_lst = sd.split(" ")
    sd_lst = [float(i) for i in sd_lst]

    sd_arr = np.asarray(sd_lst)
    sd_arr = np.split(sd_arr, len(sd_arr)/3)
    
    return np.asarray(sd_arr)

# %% [markdown]
# #### Adding Mean Average Distance

# %%
def calculate_mad(data, axis=None):
    return np.mean(np.absolute(data - np.mean(data, axis)), axis)

# %%
mads = []
for i, _ in df_data.iterrows():
    mad = df_data["SegmentData"][i]
    mad_arr = string_to_ndarray(mad)
    mad = calculate_mad(mad_arr[:,0])
    mads.append(mad)

col = pd.Series(mads)
df_data["mad_SegmentData"] = col.values

# %%
# df_data = df_data.drop("Color", axis=1)
display(df_data)
df_data.to_csv(path_or_buf="../Data/preprocessed_alcohol_balance.csv", index=False)
# Out:
#       TestID Conditie  SubjectID  SegmentNr WalkingDirection  \
# 0    006A01'     norm          6          1             away
# 1    006A01'     norm          6          2          towards
# 2    006A01'     norm          6          3             away
# 3    006A01'     norm          6          4          towards
# 4    009A01'     norm          9          1             away
# 5    009A01'     norm          9          2          towards
# 6    009A01'     norm          9          3             away
# 7    009A01'     norm          9          4          towards
# 8    010A01'     norm         10          1             away
# 9    010A01'     norm         10          2          towards
# 10   010A01'     norm         10          3             away
# 11   010A01'     norm         10          4          towards
# 12   011A01'     norm         11          1             away
# 13   011A01'     norm         11          2          towards
# ...

# %% [markdown]
# #### Adding Standard deviations

# %%
stds = []
for i, _ in df_data.iterrows():
    sd = df_data["SegmentData"][i]
    sd_arr = string_to_ndarray(sd)
    std = np.std(sd_arr[:,0])
    stds.append(std)

col = pd.Series(stds)
df_data["std_SegmentData"] = col.values

# %%
display(df_data)
df_data.to_csv(path_or_buf="../Data/preprocessed_alcohol_balance.csv", index=False)
# Out:
#        TestID Conditie  SubjectID  SegmentNr WalkingDirection  \
# 0     006A01'     norm          6          1             away
# 1     006A01'     norm          6          2          towards
# 2     006A01'     norm          6          3             away
# 3     006A01'     norm          6          4          towards
# 4     009A01'     norm          9          1             away
# 5     009A01'     norm          9          2          towards
# 6     009A01'     norm          9          3             away
# 7     009A01'     norm          9          4          towards
# 8     010A01'     norm         10          1             away
# 9     010A01'     norm         10          2          towards
# 10    010A01'     norm         10          3             away
# 11    010A01'     norm         10          4          towards
# 12    011A01'     norm         11          1             away
# 13    011A01'     norm         11          2          towards
# ...

# %%
categories = np.unique(df_data["Conditie"])
colors = np.linspace(0, 1, len(categories))
colordict = dict(zip(categories, colors)) 

df_data["Color"] = df_data["Conditie"].apply(lambda x: colordict[x])
plt.scatter(df_data["SubjectID"], df_data["std_SegmentData"], c=df_data.Color, s=15)
plt.title("Standard Deviations per Subject")
plt.show()

plt.scatter(df_data["Age"], df_data["std_SegmentData"], c=df_data.Color, s=15)
plt.title("Standard Deviations per age")
plt.show()

plt.scatter(df_data["Weight"], df_data["std_SegmentData"], c=df_data.Color, s=15)
plt.title("Standard Deviations per weight")
plt.show()

plt.scatter(df_data["Height"], df_data["std_SegmentData"], c=df_data.Color, s=15)
plt.title("Standard Deviations per height")
plt.show()

# %% [markdown]
# #### Adding variance

# %%
varss = []
for i in range(0, 720):
    sd = df_data["SegmentData"][i]
    sd_arr = string_to_ndarray(sd)
    var = np.var(sd_arr[:,0])
    varss.append(var)

col = pd.Series(varss)
df_data["var_SegmentData"] = col.values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-65dfc467549a> in <module>()
#       7
#       8 col = pd.Series(varss)
# ----> 9 df_data["var_SegmentData"] = col.values
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3117         else:
#    3118             # set column
# -> 3119             self._set_item(key, value)
#    3120
#    3121     def _setitem_slice(self, key, value):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3192
#    3193         self._ensure_valid_index(value)
# -> 3194         value = self._sanitize_column(key, value)
#    3195         NDFrame._set_item(self, key, value)
#    3196
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3389
# ...

# %%
categories = np.unique(df_data["Conditie"])
colors = np.linspace(0, 1, len(categories))
colordict = dict(zip(categories, colors)) 

df_data["Color"] = df_data["Conditie"].apply(lambda x: colordict[x])
plt.scatter(df_data["SubjectID"], df_data["var_SegmentData"], c=df_data.Color, s=15)
plt.show()

# %%
# mean std of norm
stds = []
for i in range(0, 360):
    sd = df_data["SegmentData"][i]
    sd_arr = string_to_ndarray(sd)
    std = np.std(sd_arr[:,0])
    stds.append(std)
    
print(np.mean(stds))
# Out:
# 0.03705270416192119

# %%
# mean std of bril
stds = []
for i in range(360, 720):
    sd = df_data["SegmentData"][i]
    sd_arr = string_to_ndarray(sd)
    std = np.std(sd_arr[:,0])
    stds.append(std)
    
print(np.mean(stds))
# Out:
# 0.05215266133590558

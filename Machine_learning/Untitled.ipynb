# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier  
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_fscore_support, accuracy_score  
import itertools

# %%
data = pd.read_csv("../Data/preprocessed_alcohol_balance.csv")
data = data.drop(["Unnamed: 0"], axis=1)
data['Conditie'] = data['Conditie'].map({'norm': 0,  'bril': 1})
data
# Out:
#       TestID  Conditie  SubjectID  SegmentNr WalkingDirection  \
# 0    006A01'         0          6          1             away
# 1    006A01'         0          6          2          towards
# 2    006A01'         0          6          3             away
# 3    006A01'         0          6          4          towards
# 4    009A01'         0          9          1             away
# 5    009A01'         0          9          2          towards
# 6    009A01'         0          9          3             away
# 7    009A01'         0          9          4          towards
# 8    010A01'         0         10          1             away
# 9    010A01'         0         10          2          towards
# 10   010A01'         0         10          3             away
# 11   010A01'         0         10          4          towards
# 12   011A01'         0         11          1             away
# 13   011A01'         0         11          2          towards
# 14   011A01'         0         11          3             away
# 15   011A01'         0         11          4          towards
# 16   013A01'         0         13          1             away
# 17   013A01'         0         13          2          towards
# 18   013A01'         0         13          3             away
# 19   013A01'         0         13          4          towards
# 20   014A01'         0         14          1             away
# 21   014A01'         0         14          2          towards
# 22   014A01'         0         14          3             away
# 23   014A01'         0         14          4          towards
# 24   015A01'         0         15          1             away
# 25   015A01'         0         15          2          towards
# 26   015A01'         0         15          3             away
# 27   015A01'         0         15          4          towards
# 28   016A01'         0         16          1             away
# 29   016A01'         0         16          2          towards
# ..       ...       ...        ...        ...              ...
# 690  195B01'         1        195          3             away
# 691  195B01'         1        195          4          towards
# 692  197B01'         1        197          1             away
# 693  197B01'         1        197          2          towards
# 694  197B01'         1        197          3             away
# 695  197B01'         1        197          4          towards
# 696  205B01'         1        205          1             away
# 697  205B01'         1        205          2          towards
# 698  205B01'         1        205          3             away
# 699  205B01'         1        205          4          towards
# 700  208B01'         1        208          1             away
# 701  208B01'         1        208          2          towards
# 702  208B01'         1        208          3             away
# 703  208B01'         1        208          4          towards
# 704  209B01'         1        209          1             away
# 705  209B01'         1        209          2          towards
# 706  209B01'         1        209          3             away
# 707  209B01'         1        209          4          towards
# 708  210B01'         1        210          1             away
# 709  210B01'         1        210          2          towards
# 710  210B01'         1        210          3             away
# 711  210B01'         1        210          4          towards
# 712  211B01'         1        211          1             away
# 713  211B01'         1        211          2          towards
# 714  211B01'         1        211          3             away
# 715  211B01'         1        211          4          towards
# 716  213B01'         1        213          1             away
# 717  213B01'         1        213          2          towards
# 718  213B01'         1        213          3             away
# 719  213B01'         1        213          4          towards
#
#                                            SegmentData  Height  Weight  Age  \
# 0    [[array([[0.04697253]]) array([[-0.18321628]])...     177    70.0   20
# 1    [[array([[0.40771624]]) array([[-0.22044282]])...     177    70.0   20
# 2    [[array([[0.09305737]]) array([[-0.19160482]])...     177    70.0   20
# 3    [[array([[0.44424376]]) array([[-0.2283845]]) ...     177    70.0   20
# 4    [[array([[-0.08974021]]) array([[-0.0481508]])...     195    86.0   23
# 5    [[array([[0.47497733]]) array([[-0.09702823]])...     195    86.0   23
# 6    [[array([[0.00489379]]) array([[-0.07232992]])...     195    86.0   23
# 7    [[array([[0.51498991]]) array([[-0.09675995]])...     195    86.0   23
# 8    [[array([[-0.33516738]]) array([[-0.30029692]]...     165    65.0   28
# 9    [[array([[0.54318447]]) array([[-0.34777679]])...     165    65.0   28
# 10   [[array([[-0.22053077]]) array([[-0.32474954]]...     165    65.0   28
# 11   [[array([[0.62317591]]) array([[-0.34418139]])...     165    65.0   28
# 12   [[array([[-0.13107425]]) array([[-0.18931471]]...     179    68.0   25
# 13   [[array([[0.50506954]]) array([[-0.1927438]]) ...     179    68.0   25
# 14   [[array([[-0.17264479]]) array([[-0.1893668]])...     179    68.0   25
# 15   [[array([[0.57259009]]) array([[-0.21504004]])...     179    68.0   25
# 16   [[array([[-0.00540908]]) array([[-0.32901228]]...     168    70.0   18
# 17   [[array([[0.45941712]]) array([[-0.30269804]])...     168    70.0   18
# 18   [[array([[-0.01837704]]) array([[-0.34749748]]...     168    70.0   18
# 19   [[array([[0.54023028]]) array([[-0.34476441]])...     168    70.0   18
# 20   [[array([[0.06955417]]) array([[-0.31679932]])...     165    55.0   20
# 21   [[array([[0.46176501]]) array([[-0.35673766]])...     165    55.0   20
# 22   [[array([[-0.03811273]]) array([[-0.31855141]]...     165    55.0   20
# 23   [[array([[0.46690993]]) array([[-0.36026051]])...     165    55.0   20
# 24   [[array([[0.1732389]]) array([[-0.25912885]]) ...     176    65.0   13
# 25   [[array([[0.48263509]]) array([[-0.29721288]])...     176    65.0   13
# 26   [[array([[0.07281241]]) array([[-0.25161832]])...     176    65.0   13
# 27   [[array([[0.37556966]]) array([[-0.28573786]])...     176    65.0   13
# 28   [[array([[-0.10968536]]) array([[-0.23481989]]...     175    64.0   25
# 29   [[array([[0.62004945]]) array([[-0.24533766]])...     175    64.0   25
# ..                                                 ...     ...     ...  ...
# 690  [[array([[0.21073805]]) array([[-0.09053798]])...     194    73.0   22
# 691  [[array([[0.32988417]]) array([[-0.13586263]])...     194    73.0   22
# 692  [[array([[0.13931368]]) array([[-0.17726322]])...     182    85.0   22
# 693  [[array([[0.10829448]]) array([[-0.23353832]])...     182    85.0   22
# 694  [[array([[0.10995777]]) array([[-0.17505874]])...     182    85.0   22
# 695  [[array([[0.21514729]]) array([[-0.2457018]]) ...     182    85.0   22
# 696  [[array([[-0.01459513]]) array([[-0.0973341]])...     190    79.0   21
# 697  [[array([[0.15960106]]) array([[-0.15716306]])...     190    79.0   21
# 698  [[array([[0.11458639]]) array([[-0.10628323]])...     190    79.0   21
# 699  [[array([[0.2245843]]) array([[-0.16139102]]) ...     190    79.0   21
# 700  [[array([[0.02877618]]) array([[-0.14030862]])...     183    80.0   25
# 701  [[array([[0.2095474]]) array([[-0.22192221]]) ...     183    80.0   25
# 702  [[array([[0.01043563]]) array([[-0.19434164]])...     183    80.0   25
# 703  [[array([[0.33547577]]) array([[-0.24451172]])...     183    80.0   25
# 704  [[array([[0.18633659]]) array([[-0.16324473]])...     185    70.0   27
# 705  [[array([[0.34236496]]) array([[-0.20852026]])...     185    70.0   27
# 706  [[array([[0.20987963]]) array([[-0.13992918]])...     185    70.0   27
# 707  [[array([[0.27789229]]) array([[-0.20546079]])...     185    70.0   27
# 708  [[array([[0.10012667]]) array([[-0.16242005]])...     182    70.0   23
# 709  [[array([[0.13439395]]) array([[-0.21832828]])...     182    70.0   23
# 710  [[array([[0.07067701]]) array([[-0.15452512]])...     182    70.0   23
# 711  [[array([[0.07032949]]) array([[-0.2325752]]) ...     182    70.0   23
# 712  [[array([[0.27525199]]) array([[-0.13231472]])...     185    90.0   24
# 713  [[array([[0.10289889]]) array([[-0.21105067]])...     185    90.0   24
# 714  [[array([[0.27934191]]) array([[-0.12427507]])...     185    90.0   24
# 715  [[array([[0.08977815]]) array([[-0.2054705]]) ...     185    90.0   24
# 716  [[array([[0.18686372]]) array([[-0.2937553]]) ...     167    60.0   35
# 717  [[array([[0.14038592]]) array([[-0.33189025]])...     167    60.0   35
# 718  [[array([[0.22763765]]) array([[-0.2917431]]) ...     167    60.0   35
# 719  [[array([[0.18783211]]) array([[-0.34787732]])...     167    60.0   35
#
#            BMI  std_SegmentData  mad_SegmentData  AverageStepLength  Velocity  \
# 0    22.343516         0.060870         0.048709           0.610128  2.333333
# 1    22.343516         0.038465         0.031206           0.681944  2.066667
# 2    22.343516         0.030903         0.022252           0.713798  2.033333
# 3    22.343516         0.074751         0.060879           0.651639  2.333333
# 4    22.616700         0.028861         0.025316           0.768314  2.066667
# 5    22.616700         0.029494         0.024061           0.685495  2.300000
# 6    22.616700         0.017266         0.015080           0.689099  2.333333
# 7    22.616700         0.015360         0.013693           0.660362  2.266667
# 8    23.875115         0.068683         0.056155           0.538055  2.666667
# 9    23.875115         0.024063         0.021438           0.571604  3.000000
# 10   23.875115         0.052250         0.043262           0.558455  2.833333
# 11   23.875115         0.280137         0.260661           0.399878  4.033333
# 12   21.222808         0.022814         0.018457           0.587876  2.533333
# 13   21.222808         0.015212         0.012685           0.615677  2.466667
# 14   21.222808         0.032206         0.027731           0.539825  2.566667
# 15   21.222808         0.016816         0.014997           0.602500  2.466667
# 16   24.801587         0.021980         0.017800           0.673256  2.266667
# 17   24.801587         0.035968         0.026135           0.566287  2.666667
# 18   24.801587         0.021538         0.018351           0.659820  2.233333
# 19   24.801587         0.022755         0.020016           0.660534  2.366667
# 20   20.202020         0.031856         0.029730           0.592981  2.333333
# 21   20.202020         0.033560         0.025545           0.611484  2.266667
# 22   20.202020         0.024643         0.019708           0.594791  2.233333
# 23   20.202020         0.010010         0.008032           0.624360  2.200000
# 24   20.983988         0.065507         0.059657           0.749172  1.966667
# 25   20.983988         0.026070         0.022692           0.720071  2.066667
# 26   20.983988         0.026998         0.021519           0.715994  2.133333
# 27   20.983988         0.019655         0.017361           0.688951  2.333333
# 28   20.897959         0.023256         0.019783           0.638642  2.066667
# 29   20.897959         0.018035         0.013806           0.601964  2.133333
# ..         ...              ...              ...                ...       ...
# 690  19.396323         0.050627         0.046883           0.497180  2.933333
# 691  19.396323         0.020567         0.017430           0.473427  3.266667
# 692  25.661152         0.057251         0.051841           0.537134  3.200000
# 693  25.661152         0.036848         0.031393           0.533048  3.033333
# 694  25.661152         0.029659         0.023482           0.493562  3.300000
# 695  25.661152         0.076697         0.062482           0.492371  3.200000
# 696  21.883657         0.023550         0.019349           0.697474  2.733333
# 697  21.883657         0.043806         0.035686           0.572321  3.166667
# 698  21.883657         0.034086         0.030029           0.680521  3.166667
# 699  21.883657         0.039154         0.031302           0.629838  2.866667
# 700  23.888441         0.032731         0.029012           0.630294  2.666667
# 701  23.888441         0.090449         0.076459           0.622070  2.633333
# 702  23.888441         0.068476         0.056276           0.550078  3.000000
# 703  23.888441         0.046768         0.035689           0.640728  2.933333
# 704  20.452885         0.028930         0.025664           0.615796  2.400000
# 705  20.452885         0.079330         0.064570           0.591381  3.066667
# 706  20.452885         0.029034         0.024011           0.600263  2.700000
# 707  20.452885         0.024882         0.017513           0.576018  2.833333
# 708  21.132713         0.035247         0.028249           0.482123  2.700000
# 709  21.132713         0.049913         0.041267           0.525450  2.766667
# 710  21.132713         0.046752         0.040478           0.531016  2.733333
# 711  21.132713         0.046684         0.038701           0.540118  2.833333
# 712  26.296567         0.015917         0.013268           0.684501  2.333333
# 713  26.296567         0.043174         0.035850           0.552089  2.833333
# 714  26.296567         0.023845         0.020254           0.522799  2.800000
# 715  26.296567         0.034075         0.027859           0.565741  2.833333
# 716  21.513859         0.027013         0.023835           0.595624  2.733333
# 717  21.513859         0.036368         0.031845           0.636147  2.566667
# 718  21.513859         0.032384         0.029980           0.643767  2.533333
# 719  21.513859         0.024963         0.019216           0.637243  2.733333
#
#     Alcohol_Class  Alcohol    Balance
# 0           Sober      0.0   4.299411
# 1           Sober      0.0   4.299411
# 2           Sober      0.0   4.299411
# 3           Sober      0.0   9.259287
# 4           Sober      0.0   9.259287
# 5           Sober      0.0   1.743205
# 6           Sober      0.0   1.743205
# 7           Sober      0.0   1.743205
# 8           Sober      0.0  37.059931
# 9           Sober      0.0  37.059931
# 10          Sober      0.0  37.059931
# 11          Sober      0.0  37.059931
# 12          Sober      0.0   2.821290
# 13          Sober      0.0   2.821290
# 14          Sober      0.0   2.821290
# 15          Sober      0.0   4.725911
# 16          Sober      0.0   4.725911
# 17          Sober      0.0   4.725911
# 18          Sober      0.0   4.725911
# 19          Sober      0.0   4.524925
# 20          Sober      0.0   3.122731
# 21          Sober      0.0   3.122731
# 22          Sober      0.0   3.122731
# 23          Sober      0.0   5.022392
# 24          Sober      0.0   5.022392
# 25          Sober      0.0   5.022392
# 26          Sober      0.0   5.022392
# 27          Sober      0.0   4.189830
# 28          Sober      0.0   4.189830
# 29          Sober      0.0   4.189830
# ..            ...      ...        ...
# 690         Sober      0.3  14.349754
# 691         Sober      0.3   4.983912
# 692         Sober      0.0   4.983912
# 693         Sober      0.0   4.983912
# 694         Sober      0.0   4.983912
# 695         Sober      0.0   3.624341
# 696         Sober      0.0   3.624341
# 697         Sober      0.0   3.624341
# 698         Sober      0.0   3.624341
# 699         Sober      0.0   4.348134
# 700         Sober      0.0   4.348134
# 701         Sober      0.0   4.348134
# 702         Sober      0.0   4.348134
# 703         Sober      0.0   7.920647
# 704         Sober      0.0   7.920647
# 705         Sober      0.0   7.920647
# 706         Sober      0.0   7.920647
# 707         Sober      0.0   4.258799
# 708         Sober      0.0   4.258799
# 709         Sober      0.0   4.258799
# 710         Sober      0.0   4.258799
# 711         Sober      0.0   6.328096
# 712         Tipsy      1.0   6.328096
# 713         Tipsy      1.0   6.328096
# 714         Tipsy      1.0   6.328096
# 715         Tipsy      1.0   5.434052
# 716         Sober      0.0   5.434052
# 717         Sober      0.0   5.434052
# 718         Sober      0.0   5.434052
# 719         Sober      0.0   4.406931
#
# [720 rows x 17 columns]

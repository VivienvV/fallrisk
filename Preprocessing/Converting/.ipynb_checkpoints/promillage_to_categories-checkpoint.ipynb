# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn import datasets
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from scipy.io import loadmat
import itertools
from sklearn.metrics import confusion_matrix
import pandas as pd
from sklearn import metrics
from sklearn.naive_bayes import GaussianNB

# %%
data = pd.read_csv("../Data/preprocessed_alcoholdata_mad_std.csv") 
data = data.drop(['Unnamed: 0'], axis=1)
data
# Out:
#        TestID Conditie  SubjectID  SegmentNr WalkingDirection  \
# 0     006A01'     norm          6          1             away
# 1     006A01'     norm          6          2          towards
# 2     006A01'     norm          6          3             away
# 3     006A01'     norm          6          4          towards
# 4     009A01'     norm          9          1             away
# 5     009A01'     norm          9          2          towards
# 6     009A01'     norm          9          3             away
# 7     009A01'     norm          9          4          towards
# 8     010A01'     norm         10          1             away
# 9     010A01'     norm         10          2          towards
# 10    010A01'     norm         10          3             away
# 11    010A01'     norm         10          4          towards
# 12    011A01'     norm         11          1             away
# 13    011A01'     norm         11          2          towards
# 14    011A01'     norm         11          3             away
# 15    011A01'     norm         11          4          towards
# 16    013A01'     norm         13          1             away
# 17    013A01'     norm         13          2          towards
# 18    013A01'     norm         13          3             away
# 19    013A01'     norm         13          4          towards
# 20    014A01'     norm         14          1             away
# 21    014A01'     norm         14          2          towards
# 22    014A01'     norm         14          3             away
# 23    014A01'     norm         14          4          towards
# 24    015A01'     norm         15          1             away
# 25    015A01'     norm         15          2          towards
# 26    015A01'     norm         15          3             away
# 27    015A01'     norm         15          4          towards
# 28    016A01'     norm         16          1             away
# 29    016A01'     norm         16          2          towards
# ...       ...      ...        ...        ...              ...
# 1202  205B01'     bril        205          3             away
# 1203  205B01'     bril        205          4          towards
# 1204  206B01'     bril        206          1             away
# 1205  206B01'     bril        206          2          towards
# 1206  206B01'     bril        206          3             away
# 1207  206B01'     bril        206          4          towards
# 1208  207B01'     bril        207          1             away
# 1209  207B01'     bril        207          2          towards
# 1210  207B01'     bril        207          3             away
# 1211  207B01'     bril        207          4          towards
# 1212  208B01'     bril        208          1             away
# 1213  208B01'     bril        208          2          towards
# 1214  208B01'     bril        208          3             away
# 1215  208B01'     bril        208          4          towards
# 1216  209B01'     bril        209          1             away
# 1217  209B01'     bril        209          2          towards
# 1218  209B01'     bril        209          3             away
# 1219  209B01'     bril        209          4          towards
# 1220  210B01'     bril        210          1             away
# 1221  210B01'     bril        210          2          towards
# 1222  210B01'     bril        210          3             away
# 1223  210B01'     bril        210          4          towards
# 1224  211B01'     bril        211          1             away
# 1225  211B01'     bril        211          2          towards
# 1226  211B01'     bril        211          3             away
# 1227  211B01'     bril        211          4          towards
# 1228  213B01'     bril        213          1             away
# 1229  213B01'     bril        213          2          towards
# 1230  213B01'     bril        213          3             away
# 1231  213B01'     bril        213          4          towards
#
#                                             SegmentData  Alcohol  Height  \
# 0     [[array([[0.04697253]]) array([[-0.18321628]])...     0.00     177
# 1     [[array([[0.40771624]]) array([[-0.22044282]])...     0.00     177
# 2     [[array([[0.09305737]]) array([[-0.19160482]])...     0.00     177
# 3     [[array([[0.44424376]]) array([[-0.2283845]]) ...     0.00     177
# 4     [[array([[-0.08974021]]) array([[-0.0481508]])...     0.00     195
# 5     [[array([[0.47497733]]) array([[-0.09702823]])...     0.00     195
# 6     [[array([[0.00489379]]) array([[-0.07232992]])...     0.00     195
# 7     [[array([[0.51498991]]) array([[-0.09675995]])...     0.00     195
# 8     [[array([[-0.33516738]]) array([[-0.30029692]]...     0.00     165
# 9     [[array([[0.54318447]]) array([[-0.34777679]])...     0.00     165
# 10    [[array([[-0.22053077]]) array([[-0.32474954]]...     0.00     165
# 11    [[array([[0.62317591]]) array([[-0.34418139]])...     0.00     165
# 12    [[array([[-0.13107425]]) array([[-0.18931471]]...     0.00     179
# 13    [[array([[0.50506954]]) array([[-0.1927438]]) ...     0.00     179
# 14    [[array([[-0.17264479]]) array([[-0.1893668]])...     0.00     179
# 15    [[array([[0.57259009]]) array([[-0.21504004]])...     0.00     179
# 16    [[array([[-0.00540908]]) array([[-0.32901228]]...     0.00     168
# 17    [[array([[0.45941712]]) array([[-0.30269804]])...     0.00     168
# 18    [[array([[-0.01837704]]) array([[-0.34749748]]...     0.00     168
# 19    [[array([[0.54023028]]) array([[-0.34476441]])...     0.00     168
# 20    [[array([[0.06955417]]) array([[-0.31679932]])...     0.00     165
# 21    [[array([[0.46176501]]) array([[-0.35673766]])...     0.00     165
# 22    [[array([[-0.03811273]]) array([[-0.31855141]]...     0.00     165
# 23    [[array([[0.46690993]]) array([[-0.36026051]])...     0.00     165
# 24    [[array([[0.1732389]]) array([[-0.25912885]]) ...     0.00     176
# 25    [[array([[0.48263509]]) array([[-0.29721288]])...     0.00     176
# 26    [[array([[0.07281241]]) array([[-0.25161832]])...     0.00     176
# 27    [[array([[0.37556966]]) array([[-0.28573786]])...     0.00     176
# 28    [[array([[-0.10968536]]) array([[-0.23481989]]...     0.00     175
# 29    [[array([[0.62004945]]) array([[-0.24533766]])...     0.00     175
# ...                                                 ...      ...     ...
# 1202  [[array([[0.11458639]]) array([[-0.10628323]])...     0.00     190
# 1203  [[array([[0.2245843]]) array([[-0.16139102]]) ...     0.00     190
# 1204  [[array([[-0.11061626]]) array([[-0.19973577]]...     0.11     187
# 1205  [[array([[0.19084315]]) array([[-0.24258398]])...     0.11     187
# 1206  [[array([[0.12679486]]) array([[-0.21867792]])...     0.11     187
# 1207  [[array([[0.22683923]]) array([[-0.2263134]]) ...     0.11     187
# 1208  [[array([[0.14254062]]) array([[-0.12104823]])...     0.09     187
# 1209  [[array([[0.13854691]]) array([[-0.19223802]])...     0.09     187
# 1210  [[array([[-0.04054526]]) array([[-0.17651826]]...     0.09     187
# 1211  [[array([[0.09987281]]) array([[-0.21002547]])...     0.09     187
# 1212  [[array([[0.02877618]]) array([[-0.14030862]])...     0.00     183
# 1213  [[array([[0.2095474]]) array([[-0.22192221]]) ...     0.00     183
# 1214  [[array([[0.01043563]]) array([[-0.19434164]])...     0.00     183
# 1215  [[array([[0.33547577]]) array([[-0.24451172]])...     0.00     183
# 1216  [[array([[0.18633659]]) array([[-0.16324473]])...     0.00     185
# 1217  [[array([[0.34236496]]) array([[-0.20852026]])...     0.00     185
# 1218  [[array([[0.20987963]]) array([[-0.13992918]])...     0.00     185
# 1219  [[array([[0.27789229]]) array([[-0.20546079]])...     0.00     185
# 1220  [[array([[0.10012667]]) array([[-0.16242005]])...     0.00     182
# 1221  [[array([[0.13439395]]) array([[-0.21832828]])...     0.00     182
# 1222  [[array([[0.07067701]]) array([[-0.15452512]])...     0.00     182
# 1223  [[array([[0.07032949]]) array([[-0.2325752]]) ...     0.00     182
# 1224  [[array([[0.27525199]]) array([[-0.13231472]])...     0.00     185
# 1225  [[array([[0.10289889]]) array([[-0.21105067]])...     0.00     185
# 1226  [[array([[0.27934191]]) array([[-0.12427507]])...     0.00     185
# 1227  [[array([[0.08977815]]) array([[-0.2054705]]) ...     0.00     185
# 1228  [[array([[0.18686372]]) array([[-0.2937553]]) ...     0.00     167
# 1229  [[array([[0.14038592]]) array([[-0.33189025]])...     0.00     167
# 1230  [[array([[0.22763765]]) array([[-0.2917431]]) ...     0.00     167
# 1231  [[array([[0.18783211]]) array([[-0.34787732]])...     0.00     167
#
#       Weight  Age        BMI  AverageStepLength  mad_SegmentData  \
# 0       70.0   20  22.343516           0.610128         0.048709
# 1       70.0   20  22.343516           0.681944         0.031206
# 2       70.0   20  22.343516           0.713798         0.022252
# 3       70.0   20  22.343516           0.651639         0.060879
# 4       86.0   23  22.616700           0.768314         0.025316
# 5       86.0   23  22.616700           0.685495         0.024061
# 6       86.0   23  22.616700           0.689099         0.015080
# 7       86.0   23  22.616700           0.660362         0.013693
# 8       65.0   28  23.875115           0.538055         0.056155
# 9       65.0   28  23.875115           0.571604         0.021438
# 10      65.0   28  23.875115           0.558455         0.043262
# 11      65.0   28  23.875115           0.399878         0.260661
# 12      68.0   25  21.222808           0.587876         0.018457
# 13      68.0   25  21.222808           0.615677         0.012685
# 14      68.0   25  21.222808           0.539825         0.027731
# 15      68.0   25  21.222808           0.602500         0.014997
# 16      70.0   18  24.801587           0.673256         0.017800
# 17      70.0   18  24.801587           0.566287         0.026135
# 18      70.0   18  24.801587           0.659820         0.018351
# 19      70.0   18  24.801587           0.660534         0.020016
# 20      55.0   20  20.202020           0.592981         0.029730
# 21      55.0   20  20.202020           0.611484         0.025545
# 22      55.0   20  20.202020           0.594791         0.019708
# 23      55.0   20  20.202020           0.624360         0.008032
# 24      65.0   13  20.983988           0.749172         0.059657
# 25      65.0   13  20.983988           0.720071         0.022692
# 26      65.0   13  20.983988           0.715994         0.021519
# 27      65.0   13  20.983988           0.688951         0.017361
# 28      64.0   25  20.897959           0.638642         0.019783
# 29      64.0   25  20.897959           0.601964         0.013806
# ...      ...  ...        ...                ...              ...
# 1202    79.0   21  21.883657           0.680521         0.030029
# 1203    79.0   21  21.883657           0.629838         0.031302
# 1204    95.0   20  27.166919           0.449296         0.097447
# 1205    95.0   20  27.166919           0.556618         0.049390
# 1206    95.0   20  27.166919           0.366428         0.040629
# 1207    95.0   20  27.166919           0.485693         0.043122
# 1208    73.0   23  20.875633           0.674795         0.054448
# Alle eerder genoemde effecten versterken. Ook ga je je overdreven emotioneel gedragen en je zelfkritiek verdwijnt. Je gezicht wordt rood, zwelt op en je pupillen vergroten. Je kan misselijk worden en braken.

# %%
data['Alcohol'] = data['Alcohol'].astype(float)
conditions = [
    (data['Alcohol'] > 0) & (data['Alcohol'] <= 0.5),
    (data['Alcohol'] > 0.5) & (data['Alcohol'] <= 1.5),
    (data['Alcohol'] > 1.5)]
choices = ['Light', 'Tipsy', 'Drunk']
data['Alcohol'] = np.select(conditions, choices, default='Sober')

data.to_csv("../Data/preprocessed_alcoholdata_full.csv")

# %%
pd.read_csv("../Data/preprocessed_alcoholdata_full.csv")
# Out:
#       Unnamed: 0   TestID Conditie  SubjectID  SegmentNr WalkingDirection  \
# 0              0  006A01'     norm          6          1             away
# 1              1  006A01'     norm          6          2          towards
# 2              2  006A01'     norm          6          3             away
# 3              3  006A01'     norm          6          4          towards
# 4              4  009A01'     norm          9          1             away
# 5              5  009A01'     norm          9          2          towards
# 6              6  009A01'     norm          9          3             away
# 7              7  009A01'     norm          9          4          towards
# 8              8  010A01'     norm         10          1             away
# 9              9  010A01'     norm         10          2          towards
# 10            10  010A01'     norm         10          3             away
# 11            11  010A01'     norm         10          4          towards
# 12            12  011A01'     norm         11          1             away
# 13            13  011A01'     norm         11          2          towards
# 14            14  011A01'     norm         11          3             away
# 15            15  011A01'     norm         11          4          towards
# 16            16  013A01'     norm         13          1             away
# 17            17  013A01'     norm         13          2          towards
# 18            18  013A01'     norm         13          3             away
# 19            19  013A01'     norm         13          4          towards
# 20            20  014A01'     norm         14          1             away
# 21            21  014A01'     norm         14          2          towards
# 22            22  014A01'     norm         14          3             away
# 23            23  014A01'     norm         14          4          towards
# 24            24  015A01'     norm         15          1             away
# 25            25  015A01'     norm         15          2          towards
# 26            26  015A01'     norm         15          3             away
# 27            27  015A01'     norm         15          4          towards
# 28            28  016A01'     norm         16          1             away
# 29            29  016A01'     norm         16          2          towards
# ...          ...      ...      ...        ...        ...              ...
# 1202        1202  205B01'     bril        205          3             away
# 1203        1203  205B01'     bril        205          4          towards
# 1204        1204  206B01'     bril        206          1             away
# 1205        1205  206B01'     bril        206          2          towards
# 1206        1206  206B01'     bril        206          3             away
# 1207        1207  206B01'     bril        206          4          towards
# 1208        1208  207B01'     bril        207          1             away
# 1209        1209  207B01'     bril        207          2          towards
# 1210        1210  207B01'     bril        207          3             away
# 1211        1211  207B01'     bril        207          4          towards
# 1212        1212  208B01'     bril        208          1             away
# 1213        1213  208B01'     bril        208          2          towards
# 1214        1214  208B01'     bril        208          3             away
# 1215        1215  208B01'     bril        208          4          towards
# 1216        1216  209B01'     bril        209          1             away
# 1217        1217  209B01'     bril        209          2          towards
# 1218        1218  209B01'     bril        209          3             away
# 1219        1219  209B01'     bril        209          4          towards
# 1220        1220  210B01'     bril        210          1             away
# 1221        1221  210B01'     bril        210          2          towards
# 1222        1222  210B01'     bril        210          3             away
# 1223        1223  210B01'     bril        210          4          towards
# 1224        1224  211B01'     bril        211          1             away
# 1225        1225  211B01'     bril        211          2          towards
# 1226        1226  211B01'     bril        211          3             away
# 1227        1227  211B01'     bril        211          4          towards
# 1228        1228  213B01'     bril        213          1             away
# 1229        1229  213B01'     bril        213          2          towards
# 1230        1230  213B01'     bril        213          3             away
# 1231        1231  213B01'     bril        213          4          towards
#
#                                             SegmentData Alcohol  Height  \
# 0     [[array([[0.04697253]]) array([[-0.18321628]])...   Sober     177
# 1     [[array([[0.40771624]]) array([[-0.22044282]])...   Sober     177
# 2     [[array([[0.09305737]]) array([[-0.19160482]])...   Sober     177
# 3     [[array([[0.44424376]]) array([[-0.2283845]]) ...   Sober     177
# 4     [[array([[-0.08974021]]) array([[-0.0481508]])...   Sober     195
# 5     [[array([[0.47497733]]) array([[-0.09702823]])...   Sober     195
# 6     [[array([[0.00489379]]) array([[-0.07232992]])...   Sober     195
# 7     [[array([[0.51498991]]) array([[-0.09675995]])...   Sober     195
# 8     [[array([[-0.33516738]]) array([[-0.30029692]]...   Sober     165
# 9     [[array([[0.54318447]]) array([[-0.34777679]])...   Sober     165
# 10    [[array([[-0.22053077]]) array([[-0.32474954]]...   Sober     165
# 11    [[array([[0.62317591]]) array([[-0.34418139]])...   Sober     165
# 12    [[array([[-0.13107425]]) array([[-0.18931471]]...   Sober     179
# 13    [[array([[0.50506954]]) array([[-0.1927438]]) ...   Sober     179
# 14    [[array([[-0.17264479]]) array([[-0.1893668]])...   Sober     179
# 15    [[array([[0.57259009]]) array([[-0.21504004]])...   Sober     179
# 16    [[array([[-0.00540908]]) array([[-0.32901228]]...   Sober     168
# 17    [[array([[0.45941712]]) array([[-0.30269804]])...   Sober     168
# 18    [[array([[-0.01837704]]) array([[-0.34749748]]...   Sober     168
# 19    [[array([[0.54023028]]) array([[-0.34476441]])...   Sober     168
# 20    [[array([[0.06955417]]) array([[-0.31679932]])...   Sober     165
# 21    [[array([[0.46176501]]) array([[-0.35673766]])...   Sober     165
# 22    [[array([[-0.03811273]]) array([[-0.31855141]]...   Sober     165
# 23    [[array([[0.46690993]]) array([[-0.36026051]])...   Sober     165
# 24    [[array([[0.1732389]]) array([[-0.25912885]]) ...   Sober     176
# 25    [[array([[0.48263509]]) array([[-0.29721288]])...   Sober     176
# 26    [[array([[0.07281241]]) array([[-0.25161832]])...   Sober     176
# 27    [[array([[0.37556966]]) array([[-0.28573786]])...   Sober     176
# 28    [[array([[-0.10968536]]) array([[-0.23481989]]...   Sober     175
# 29    [[array([[0.62004945]]) array([[-0.24533766]])...   Sober     175
# ...                                                 ...     ...     ...
# 1202  [[array([[0.11458639]]) array([[-0.10628323]])...   Sober     190
# 1203  [[array([[0.2245843]]) array([[-0.16139102]]) ...   Sober     190
# 1204  [[array([[-0.11061626]]) array([[-0.19973577]]...   Light     187
# 1205  [[array([[0.19084315]]) array([[-0.24258398]])...   Light     187
# 1206  [[array([[0.12679486]]) array([[-0.21867792]])...   Light     187
# 1207  [[array([[0.22683923]]) array([[-0.2263134]]) ...   Light     187
# 1208  [[array([[0.14254062]]) array([[-0.12104823]])...   Light     187
# 1209  [[array([[0.13854691]]) array([[-0.19223802]])...   Light     187
# 1210  [[array([[-0.04054526]]) array([[-0.17651826]]...   Light     187
# 1211  [[array([[0.09987281]]) array([[-0.21002547]])...   Light     187
# 1212  [[array([[0.02877618]]) array([[-0.14030862]])...   Sober     183
# 1213  [[array([[0.2095474]]) array([[-0.22192221]]) ...   Sober     183
# 1214  [[array([[0.01043563]]) array([[-0.19434164]])...   Sober     183
# 1215  [[array([[0.33547577]]) array([[-0.24451172]])...   Sober     183
# 1216  [[array([[0.18633659]]) array([[-0.16324473]])...   Sober     185
# 1217  [[array([[0.34236496]]) array([[-0.20852026]])...   Sober     185
# 1218  [[array([[0.20987963]]) array([[-0.13992918]])...   Sober     185
# 1219  [[array([[0.27789229]]) array([[-0.20546079]])...   Sober     185
# 1220  [[array([[0.10012667]]) array([[-0.16242005]])...   Sober     182
# 1221  [[array([[0.13439395]]) array([[-0.21832828]])...   Sober     182
# 1222  [[array([[0.07067701]]) array([[-0.15452512]])...   Sober     182
# 1223  [[array([[0.07032949]]) array([[-0.2325752]]) ...   Sober     182
# 1224  [[array([[0.27525199]]) array([[-0.13231472]])...   Sober     185
# 1225  [[array([[0.10289889]]) array([[-0.21105067]])...   Sober     185
# 1226  [[array([[0.27934191]]) array([[-0.12427507]])...   Sober     185
# 1227  [[array([[0.08977815]]) array([[-0.2054705]]) ...   Sober     185
# 1228  [[array([[0.18686372]]) array([[-0.2937553]]) ...   Sober     167
# 1229  [[array([[0.14038592]]) array([[-0.33189025]])...   Sober     167
# 1230  [[array([[0.22763765]]) array([[-0.2917431]]) ...   Sober     167
# 1231  [[array([[0.18783211]]) array([[-0.34787732]])...   Sober     167
#
#       Weight  Age        BMI  AverageStepLength  mad_SegmentData  \
# 0       70.0   20  22.343516           0.610128         0.048709
# 1       70.0   20  22.343516           0.681944         0.031206
# 2       70.0   20  22.343516           0.713798         0.022252
# 3       70.0   20  22.343516           0.651639         0.060879
# 4       86.0   23  22.616700           0.768314         0.025316
# 5       86.0   23  22.616700           0.685495         0.024061
# 6       86.0   23  22.616700           0.689099         0.015080
# 7       86.0   23  22.616700           0.660362         0.013693
# 8       65.0   28  23.875115           0.538055         0.056155
# 9       65.0   28  23.875115           0.571604         0.021438
# 10      65.0   28  23.875115           0.558455         0.043262
# 11      65.0   28  23.875115           0.399878         0.260661
# 12      68.0   25  21.222808           0.587876         0.018457
# 13      68.0   25  21.222808           0.615677         0.012685
# 14      68.0   25  21.222808           0.539825         0.027731
# 15      68.0   25  21.222808           0.602500         0.014997
# 16      70.0   18  24.801587           0.673256         0.017800
# 17      70.0   18  24.801587           0.566287         0.026135
# 18      70.0   18  24.801587           0.659820         0.018351
# 19      70.0   18  24.801587           0.660534         0.020016
# 20      55.0   20  20.202020           0.592981         0.029730
# 21      55.0   20  20.202020           0.611484         0.025545
# 22      55.0   20  20.202020           0.594791         0.019708
# 23      55.0   20  20.202020           0.624360         0.008032
# 24      65.0   13  20.983988           0.749172         0.059657
